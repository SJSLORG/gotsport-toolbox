# %% [markdown]
# ### Outline of the Code
#
# 1. **Imports**:
#    - [`pandas`](command:_github.copilot.openSymbolFromReferences?%5B%22pandas%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A7%7D%7D%5D%5D "Go to definition") is imported as [`pd`](command:_github.copilot.openSymbolFromReferences?%5B%22pd%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A17%7D%7D%5D%5D "Go to definition") for data manipulation.
#    - [`time`](command:_github.copilot.openSymbolFromReferences?%5B%22time%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A3%2C%22character%22%3A5%7D%7D%5D%5D "Go to definition") is imported from the [`time`](command:_github.copilot.openSymbolFromReferences?%5B%22time%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A3%2C%22character%22%3A5%7D%7D%5D%5D "Go to definition") module.
#
# 2. **Function Definitions**:
#    - [`custom_replace(row, prefix)`](command:_github.copilot.openSymbolFromReferences?%5B%22custom_replace(row%2C%20prefix)%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A4%7D%7D%5D%5D "Go to definition"): This function takes a row from a DataFrame and a prefix (either 'Home' or 'Away'). It checks if the team name starts with the club name and adjusts the team name accordingly.
#    - [`insert_space(string, integer)`](command:_github.copilot.openSymbolFromReferences?%5B%22insert_space(string%2C%20integer)%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A18%2C%22character%22%3A4%7D%7D%5D%5D "Go to definition"): This function inserts a space into a string at a specified position.
#
# 3. **File Paths**:
#    - [`root`](command:_github.copilot.openSymbolFromReferences?%5B%22root%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A22%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition"), [`export_file`](command:_github.copilot.openSymbolFromReferences?%5B%22export_file%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A23%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition"), [`import_file_folder`](command:_github.copilot.openSymbolFromReferences?%5B%22import_file_folder%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A24%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition"), and [`import_file_name`](command:_github.copilot.openSymbolFromReferences?%5B%22import_file_name%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A25%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition") are defined to specify the paths for reading and writing files.
#
# 4. **Reading Excel File**:
#    - The Excel file specified by [`import_file_folder`](command:_github.copilot.openSymbolFromReferences?%5B%22import_file_folder%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A24%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition") and [`import_file_name`](command:_github.copilot.openSymbolFromReferences?%5B%22import_file_name%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A25%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition") is read into a DataFrame [`gs_data`](command:_github.copilot.openSymbolFromReferences?%5B%22gs_data%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A29%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition") using [`pd.read_excel`](command:_github.copilot.openSymbolFromReferences?%5B%22pd.read_excel%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A17%7D%7D%5D%5D "Go to definition").
#
# 5. **Creating DataFrame**:
#    - A new DataFrame [`gs_data_df`](command:_github.copilot.openSymbolFromReferences?%5B%22gs_data_df%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A31%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition") is created with specific columns from [`gs_data`](command:_github.copilot.openSymbolFromReferences?%5B%22gs_data%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A29%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition").
#
# 6. **Replacing Team Names**:
#    - The 'Away Team' and 'Home Team' columns are updated by removing the corresponding 'Away Club' and 'Home Club' names from the team names.
#
# 7. **Applying Custom Replace Function**:
#    - The [`custom_replace`](command:_github.copilot.openSymbolFromReferences?%5B%22custom_replace%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A4%7D%7D%5D%5D "Go to definition") function is applied to the 'Home Team' and 'Away Team' columns to further adjust the team names.
#
# 8. **Converting to Upper Case**:
#    - The 'Home Team' column is converted to upper case.
#
# 9. **Displaying DataFrame**:
#    - The first few rows of the processed DataFrame are displayed using [`gs_data_df.head()`](command:_github.copilot.openSymbolFromReferences?%5B%22gs_data_df.head()%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%23W1sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Froxberry%2FWorkspaces%2FSJSL%2Fgotsport-toolbox%2Farbiter_etl%2Farbiter_import.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A31%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition").

# %% [markdown]
# ```mermaid
# sequenceDiagram
#     participant User
#     participant Script
#     participant ExcelFile
#     participant DataFrame
#
#     User->>Script: Run script
#     Script->>ExcelFile: Read Excel file
#     ExcelFile-->>Script: Return data
#     Script->>DataFrame: Create DataFrame from Excel data
#     Script->>DataFrame: Replace 'Away Team' names
#     Script->>DataFrame: Replace 'Home Team' names
#     Script->>DataFrame: Apply custom_replace to 'Home Team'
#     Script->>DataFrame: Apply custom_replace to 'Away Team'
#     Script->>DataFrame: Convert 'Home Team' to upper case
#     Script->>User: Display DataFrame head
# ```

# %%
# Arbiter Operations
# 1. import schedule
import pandas as pd
from time import time

def custom_replace(row, prefix):
    club_key = f'{prefix} Club'
    team_key = f'{prefix} Team'
    first_club = row[club_key][:5]
    starts_with_club = row[team_key].strip().startswith(first_club)

    if starts_with_club:
        result = row[team_key].strip()
    else:
        result = row[club_key].strip() + ' ' + row[team_key].strip()  # No change if the first 10 letters don't match

    return result
    
def insert_space(string, integer):
    adjust_retval = string[0:integer] + ' ' + string[integer:]
    return adjust_retval

root = 'arbiter_etl/data/fall2024/'
export_file = root + 'export/'
import_file_folder = root + 'import/'
import_file_name = '2024-05-final-2-7-24.master-schedule.2024-04-29T153711.951-0400.xlsx'

import_file_name = 'arbiter_etl/data/fall2024/import/final-2024-v1-8-4-24.master-schedule.2024-09-23T003214.646-0400.xlsx'

gs_data = pd.read_excel(import_file_name, sheet_name='Matches')

gs_data_df = pd.DataFrame(gs_data, columns = ['Date', 'Start Time', 'ID', 'Age', 'Home Club', 'Home Team', 'Away Club', 'Away Team', 'Venue', 'Pitch'])

gs_data_df['Away Team'] = gs_data_df['Away Team'].replace(gs_data_df['Away Club'].tolist(), '', regex=True, limit=1)
gs_data_df['Home Team'] = gs_data_df['Home Team'].replace(gs_data_df['Home Club'].tolist(), '', regex=True, limit=1)

gs_data_df['Home Team'] = gs_data_df.apply(custom_replace, prefix='Home', axis=1)
gs_data_df['Away Team'] = gs_data_df.apply(custom_replace, prefix='Away', axis=1)

gs_data_df['Home Team'] = gs_data_df['Home Team'].str.upper()

gs_data_df.head()
